# %%
import fire
import uuid
import textwrap
from llama_stack_client import LlamaStackClient, Agent, AgentEventLogger, RAGDocument
from llama_stack_client.types import Document
from termcolor import colored
from utils import check_model_is_available, get_any_available_model

# %%
llama_stack_endpoint=f"http://172.206.50.74:5001"

client = LlamaStackClient(
    base_url=llama_stack_endpoint,
    provider_data={"tavily_search_api_key": "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"},
)

# %% [markdown]
# Registarmos la Base RAG

# %%
# Create a vector database instance

vector_db_id = f"v{uuid.uuid4().hex}"

embed_lm = next(m for m in client.models.list() if m.model_type == "embedding")
embedding_model = embed_lm.identifier
client.vector_dbs.register(
    vector_db_id=vector_db_id,
    embedding_model=embedding_model,
    embedding_dimension=384,
    provider_id="faiss",
)
# Out:
# VectorDBRegisterResponse(embedding_dimension=384, embedding_model='all-MiniLM-L6-v2', identifier='vb56497342f3448b386835167984f017e', provider_id='faiss', provider_resource_id='vb56497342f3448b386835167984f017e', type='vector_db', access_attributes=None)

# %% [markdown]
# Configuración Parametros documetos

# %%
urls = [
    "Politicas.txt",
]

# %% [markdown]
# Generamos lista de documentos:

# %%
documents = [
    RAGDocument(
        document_id=f"num-{i}",
        content=f"https://raw.githubusercontent.com/pmontiveros/llama-stack-demo/refs/heads/main/data/Politicas/{url}",
        mime_type="text/plain",
        metadata={},
    )
    for i, url in enumerate(urls)
    ##print(documents)
]

# %% [markdown]
# Insertamos los documentos en nuestra base RAG

# %%
# Insert documents
client.tool_runtime.rag_tool.insert(
    documents=documents,
    vector_db_id=vector_db_id,
    chunk_size_in_tokens=32,
)

# %% [markdown]
# Consultar Resultados:

# %%
chunks_response = client.vector_io.query(
    vector_db_id=vector_db_id, query="Kuak"
)
print(chunks_response)
# Out:
# QueryChunksResponse(chunks=[Chunk(content='Kuak S.A. es una firma multinacional de servicios de auditoría, consultoría y Advisory con 80000 empleados alrededor del', metadata={'token_count': 32.0, 'document_id': 'num-0'}), Chunk(content='80000 empleados alrededor del mundo. \nLas unidades de cariño, en En Kuak S.A., son un sistema complementario de re', metadata={'token_count': 32.0, 'document_id': 'num-0'}), Chunk(content=' o estratégicos. Además, Kuak, implementa una novedosa política de crédito donde los empleados pueden pedir unidades de cariño', metadata={'token_count': 32.0, 'document_id': 'num-0'})], scores=[0.6805231406121912, 0.6561670341890029, 0.6133212822632927])

# %% [markdown]
# ## Seleccionamos el modelo activo en el Stack

# %%
def identificar_intencion(user_prompt:str) -> int:
    #Versión Mock
    """
        Identifica la intención del usuario.
        :param user_prompt: Pregunta del usuario
        :return: La intención del usuario que puede ser  una Consulta, una Solicitud o un Reclamao]
    """
    opciones = ["Reclamo", "Consulta", "Solicitud"]
    return random.choice(opciones)

# %%
available_shields = [shield.identifier for shield in client.shields.list()]
if not available_shields:
    print(colored("No available shields. Disabling safety.", "yellow"))
else:
    print(f"Available shields found: {available_shields}")

model_id= None

if model_id is None:
    model_id = get_any_available_model(client)
    if model_id is None:
        sys.exit("No hay un modelo")
else:
    if not check_model_is_available(client, model_id):
        sys.exit("El modelo no esta disponible")

print(f"Using model: {model_id}")
# Out:
# No available shields. Disabling safety.
# Using model: meta-llama/Llama-3.2-3B-Instruct

# %%
    agent = Agent(
        client,
        model=model_id,
        instructions=textwrap.dedent(
                """
                    Eres un asistente que debe identificar la intencion del usuario al hacer una pregunta. Tú Debes utilizar la herramienta identificar_intencion en cada pregunta que haga el usuario. 
                    Busca en el RAG todo lo que el usuario pregunte.
                    Responde de manera breve y consisa
                """
            ),
        #tools=["builtin::websearch"],
            tools=[
            {
                "name": "builtin::rag/knowledge_search",
                "args": {"vector_db_ids": [vector_db_id]},
            },identificar_intencion
        ],
        input_shields=available_shields,
        output_shields=available_shields,
        enable_session_persistence=False,
    )

# %%
session_id = agent.create_session(session_name=f"s{uuid.uuid4().hex}")

# %%
user_inputs = ["¿Que es Kuak?","¿Que Son las Unidades de cariño?"]

# %%
for t in turns:
    print("user>", t)
    turn_response = agent.create_turn(
        messages=[{"role": "user", "content": t}], session_id=session_id, stream=False
    )
    #for event in AgentEventLogger().log(turn_response):
    #    event.print()
    if turn_response.output_message.tool_calls:
        for tool_call in turn_response.output_message.tool_calls:
            if tool_call["tool_name"]=="identificar_intencion":
                aux=tool_call
# Out:
# user> ¿Que es Kuak?
# user> ¿Que Son las Unidades de cariño?

# %%
print(turn_response)
# Out:
# Turn(input_messages=[UserMessage(content='¿Que Son las Unidades de cariño?', role='user', context=None)], output_message=CompletionMessage(content='No se encontró información directa sobre "Unidades de cariño" en el RAG. Sin embargo, se puede inferir que se refiere a unidades de medida de cariño, como el "unidades de cariño" en el contexto de la física o la biología, que pueden referirse a unidades de medida de energía o calor. También podría referirse a unidades de medida de afecto o cariño en un contexto más emocional o social.', role='assistant', stop_reason='end_of_turn', tool_calls=[]), session_id='59b8a922-b42c-4e6c-b4cb-8a2c27e45dde', started_at=datetime.datetime(2025, 5, 7, 8, 10, 9, 487616, tzinfo=TzInfo(UTC)), steps=[InferenceStep(api_model_response=CompletionMessage(content='', role='assistant', stop_reason='end_of_turn', tool_calls=[ToolCall(arguments={'user_prompt': '¿Qué son las Unidades de cariño?'}, call_id='6315c479-59f0-4b3b-b24a-46a8ce6822c5', tool_name='identificar_intencion', arguments_json='{"user_prompt": "\\u00bfQu\\u00e9 son las Unidades de cari\\u00f1o?"}')]), step_id='28741359-e6f0-4b54-807e-9d3022e22c0e', step_type='inference', turn_id='33ec647b-a5a6-4975-bcd9-8f25e7fb0fe6', completed_at=datetime.datetime(2025, 5, 7, 8, 10, 12, 650300, tzinfo=TzInfo(UTC)), started_at=datetime.datetime(2025, 5, 7, 8, 10, 9, 487673, tzinfo=TzInfo(UTC))), ToolExecutionStep(step_id='28741359-e6f0-4b54-807e-9d3022e22c0e', step_type='tool_execution', tool_calls=[ToolCall(arguments={'user_prompt': '¿Qué son las Unidades de cariño?'}, call_id='6315c479-59f0-4b3b-b24a-46a8ce6822c5', tool_name='identificar_intencion', arguments_json='{"user_prompt": "\\u00bfQu\\u00e9 son las Unidades de cari\\u00f1o?"}')], tool_responses=[ToolResponse(call_id='6315c479-59f0-4b3b-b24a-46a8ce6822c5', content='"Reclamar"', tool_name='identificar_intencion', metadata={})], turn_id='33ec647b-a5a6-4975-bcd9-8f25e7fb0fe6', completed_at=datetime.datetime(2025, 5, 7, 8, 10, 12, 892566, tzinfo=TzInfo(UTC)), started_at=datetime.datetime(2025, 5, 7, 8, 10, 12, 660697, tzinfo=TzInfo(UTC))), InferenceStep(api_model_response=CompletionMessage(content='No se encontró información directa sobre "Unidades de cariño" en el RAG. Sin embargo, se puede inferir que se refiere a unidades de medida de cariño, como el "unidades de cariño" en el contexto de la física o la biología, que pueden referirse a unidades de medida de energía o calor. También podría referirse a unidades de medida de afecto o cariño en un contexto más emocional o social.', role='assistant', stop_reason='end_of_turn', tool_calls=[]), step_id='cfa6728c-a610-449b-8b76-040eca44ea45', step_type='inference', turn_id='33ec647b-a5a6-4975-bcd9-8f25e7fb0fe6', completed_at=datetime.datetime(2025, 5, 7, 8, 10, 18, 711070, tzinfo=TzInfo(UTC)), started_at=datetime.datetime(2025, 5, 7, 8, 10, 12, 902862, tzinfo=TzInfo(UTC)))], turn_id='33ec647b-a5a6-4975-bcd9-8f25e7fb0fe6', completed_at=datetime.datetime(2025, 5, 7, 8, 10, 18, 721483, tzinfo=TzInfo(UTC)), output_attachments=[])

# %% [markdown]
# # Evaluación de resultados:

# %%
## Obtención de todas las respuestas de la sesion

# %%
from rich.pretty import pprint

session_response = client.agents.session.retrieve(
    session_id=session_id,
    agent_id=agent.agent_id,
)
#pprint(session_response)

# %%
eval_rows = []

expected_answers = [
    "Kuak S.A. es una firma multinacional de servicios de auditoría, consultoría y Advisory con 80000 empleados alrededor del Mundo",
    "En En Kuak S.A las unidades de cariño, son un sistema complementario de recompensas y bonificaciones",
]

for i, turn in enumerate(session_response.turns):
    eval_rows.append(
        {
            "input_query": turn.input_messages[0].content,
            "generated_answer": turn.output_message.content,
            "expected_answer": expected_answers[i],
        }
    )

pprint(eval_rows)
# Out:
# [
# │   {
# │   │   'input_query': '¿Que es Kuak?',
# │   │   'generated_answer': 'Kuak S.A. es una firma multinacional de servicios de auditoría, consultoría y Advisory con 80.000 empleados en todo el mundo. Además, la empresa implementa un sistema de unidades de cariño para sus empleados, que pueden pedir unidades de cariño como forma de recompensa o estrategia para motivar a sus empleados. Los jefes también pueden otorgar unidades de cariño a sus empleados como forma de reconocimiento o recompensa por su trabajo.',
# │   │   'expected_answer': 'Kuak S.A. es una firma multinacional de servicios de auditoría, consultoría y Advisory con 80000 empleados alrededor del Mundo'
# │   },
# │   {
# │   │   'input_query': '¿Que Son las Unidades de cariño?',
# │   │   'generated_answer': 'No se encontraron resultados relevantes.',
# │   │   'expected_answer': 'En En Kuak S.A las unidades de cariño, son un sistema complementario de recompensas y bonificaciones'
# │   }
# ]

# %%
scoring_params = {
    "basic::subset_of": None,
}
scoring_response = client.scoring.score(
    input_rows=eval_rows, scoring_functions=scoring_params
)
pprint(scoring_response)
# Out:
# ScoringScoreResponse(
# │   results={
# │   │   'basic::subset_of': ScoringResult(
# │   │   │   aggregated_results={'accuracy': {'accuracy': 0.0, 'num_correct': 0.0, 'num_total': 2}},
# │   │   │   score_rows=[{'score': 0.0}, {'score': 0.0}]
# │   │   )
# │   }
# )

# %% [markdown]
# # Anexo

# %% [raw]
# client.vector_dbs.unregister(vector_db_id)

# %% [markdown]
# ## Listamos Bases Preexistentes:

# %% [raw]
# list=client.vector_dbs.list()
# print(list)

# %% [raw]
# # Unregister all vector databases
# for vector_db_id in client.vector_dbs.list():
#     print(f"Unregistering vector database: {vector_db_id.identifier}")
#     client.vector_dbs.unregister(vector_db_id=vector_db_id.identifier)
